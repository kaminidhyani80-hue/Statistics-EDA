# %% [markdown]
# # Statistics Practice Notebook (Questions Only)
#
# ## Dataset A
# `5, 7, 7, 10, 12, 15, 18, 20, 22, 25`

# %% [markdown]
# ## Part 1: Mean, Median, Mode
# 1. Find the mean of Dataset A.
# 2. Find the median of Dataset A.
# 3. Find the mode of Dataset A.
# 4. If 100 is added to Dataset A, what happens to the mean?
# 5. If 100 is added, what happens to the median?

# %%
import pandas as pd

a = pd.Series([5, 7, 7, 10, 12, 15, 18, 20, 22, 25])
print(a.mean())
print(a.median())
print(a.mode())
# Out:
# 14.1
# 13.5
# 0    7
# dtype: int64

# %%
print((a+100).mean())
print((a+100).median())
# Out:
# 114.1
# 113.5

# %% [markdown]
# ## Part 2: Variance & Standard Deviation
# 6. Calculate the variance of Dataset A.
# 7. Calculate the standard deviation of Dataset A.
#
# ## Dataset B
# `10, 10, 10, 10, 10`
#
# 8. Find mean, variance, and standard deviation of Dataset B.
# 9. Compare spread of Dataset A and Dataset B.

# %%
print(a.var())
print(a.std())
# Out:
# 48.544444444444444
# 6.967384333050994

# %%
b = pd.Series([10, 10, 10, 10, 10])
print(a.mean())
print(b.var())
print(b.std())
# Out:
# 14.1
# 0.0
# 0.0

# %% [markdown]
# ## Part 3: Percentiles & Quartiles
# 10. Find the 25th percentile of Dataset A.
# 11. Find the 50th percentile of Dataset A.
# 12. Find the 75th percentile of Dataset A.
# 13. Find Q1, Q2, Q3 for Dataset A.
# 14. Identify values below Q1 and above Q3.

# %%
q1 = a.quantile(0.25)
q2 = a.quantile(0.5)
q3 = a.quantile(0.75)
print(q1)
print(q2)
print(q3)

below_q1 = a[a<=q1]
print(below_q1)
above_q3 = a[a>=q3]
print(above_q3)
# Out:
# 7.75
# 13.5
# 19.5
# 0    5
# 1    7
# 2    7
# dtype: int64
# 7    20
# 8    22
# 9    25
# dtype: int64

# %% [markdown]
# ## Part 4: IQR
# 15. Calculate the IQR of Dataset A.
# 16. Find the lower bound using IQR.
# 17. Find the upper bound using IQR.

# %%
iqr = q3 - q1
print(iqr)
lower_bound = q1 - 1.5*(iqr)
upper_bound = q2 + 1.5*(iqr)
print(lower_bound)
print(upper_bound)
# Out:
# 11.75
# -9.875
# 31.125

# %% [markdown]
# ## Concept-Based
# 22. Can a dataset have more than one mode?
# 23. What happens when all values are the same—mean, median, mode, variance?
# 24. If variance is zero, what does it indicate?

# %% [markdown]
# Ans 22----> Yes, A dataset can have more than one mode if multiple values occur with the same highest frequency.
#
# Ans 23----> If all values are the same, for example:
# Data = 4, 4, 4, 4, 4
#
# Mean = 4
# Median = 4
# Mode = 4
# Variance = 0
# Because every value is identical, there is no spread or variation in the data.
#
# Ans 24 ---> If the variance is 0 it means mean and median is same and data is more reliable.

# %% [markdown]
# ## Real-Life Thinking
# 25. For salary data with extreme values, should you use mean or median?
# 26. In shopping data, when is mode useful?
# 27. If a student is in the 80th percentile, what does it mean?
# 28. Which quartile represents the top 25% of data?

# %% [markdown]
# Ans 25----> For salary data with extreme values (very high or very low salaries), use the median because it is less affected by outliers than the mean.
# Ans 26----> In shopping data, mode is useful for finding the most frequently purchased product, brand, size, or payment method.
# Ans 27----> If a student is in the 80th percentile, it means the student scored higher than 80% of the students in the dataset.
# Ans 28----> The 4th quartile (Q4) represents the top 25% of the data.
